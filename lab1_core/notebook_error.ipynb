# %% [markdown]
# # Lab 1 Task B: 绘制多方法误差对比图
#
# ## 任务描述
# 1. 定义步长数组 $h$ 从 $10^{-1}$ 到 $10^{-16}$。
# 2. 调用 Task C 实现的 `forward_diff` 和 `central_diff`。
# 3. **绘制对比图**：
#    - 在同一张双对数坐标图上，画出前向差分误差和中心差分误差。
#    - 添加辅助线：$y=h$ (斜率1) 和 $y=h^2$ (斜率2)，验证理论精度。
# 4. **寻找 Sweet Spot**：两者的最佳步长分别在哪里？

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('../src') 
from differentiation import forward_diff, central_diff

# 1. 定义参数
x0 = 1.0
true_val = np.cos(x0)
h_values = 10.0**np.arange(-1, -17, -1)

# TODO: 计算两种方法的误差
# err_fwd = ...
# err_cen = ...

# TODO: 绘图
# plt.loglog(h_values, err_fwd, label='Forward O(h)')
# plt.loglog(h_values, err_cen, label='Central O(h^2)')
# ...
